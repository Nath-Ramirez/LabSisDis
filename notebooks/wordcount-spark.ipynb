# %%
# si esta en EMR o Databricks, estos objetos ya están preconstruidos:
spark
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>0</td><td>application_1763434461835_0002</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-84-237.us-west-2.compute.internal:20888/proxy/application_1763434461835_0002/">Link</a></td><td><a target="_blank" href="http://ip-172-31-80-33.us-west-2.compute.internal:8042/node/containerlogs/container_1763434461835_0002_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# <pyspark.sql.session.SparkSession object at 0x7f59399f4bd0>

# %%
# si esta en EMR o Databricks, estos objetos ya están preconstruidos:
sc
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# <SparkContext master=yarn appName=livy-session-0>

# %%
# WORDCOUNT COMPACTO
# en AWS S3
#files_rdd = sc.textFile("s3a://username_datalake/datasets/gutenberg-small/*.txt")

# en gdrive:
files_rdd = spark.sparkContext.textFile("s3://notebooksnath/data/gutenberg-small/*")


# local:
#files_rdd = sc.textFile("../datasets/gutenberg-small/*.txt")
wc_unsort = files_rdd.flatMap(lambda line: line.split()).map(lambda word: (word, 1)).reduceByKey(lambda a, b: a + b)
wc = wc_unsort.sortBy(lambda a: -a[1])
for tupla in wc.take(10):
        print(tupla)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ('the', 44647)
# ('of', 28020)
# ('to', 23208)
# ('and', 20444)
# ('in', 13174)
# ('that', 12265)
# ('I', 10880)
# ('a', 10431)
# ('is', 7776)
# ('be', 7148)

# %%
# WORDCOUNT PASO A PASO
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
files = sc.textFile("s3://notebooksnath/data/gutenberg-small/*")
for f in files.take(10):
    print(f)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# LINCOLN LETTERS
#
# By Abraham Lincoln
#
#
# Published by The Bibilophile Society

# %%
tokens = files.flatMap(lambda line: line.split())
for t in tokens.take(10):
    print(t)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# LINCOLN
# LETTERS
# By
# Abraham
# Lincoln
# Published
# by
# The
# Bibilophile
# Society

# %%
wc1 = tokens.map(lambda word: (word, 1))
for c in wc1.take(10):
    print(c)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ('LINCOLN', 1)
# ('LETTERS', 1)
# ('By', 1)
# ('Abraham', 1)
# ('Lincoln', 1)
# ('Published', 1)
# ('by', 1)
# ('The', 1)
# ('Bibilophile', 1)
# ('Society', 1)

# %%
wc = wc1.reduceByKey(lambda a, b: a + b)
for c in wc.take(10):
    print(c)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ('enters', 7)
# ('matters', 57)
# ('anxiety,', 7)
# ('but', 2485)
# ('where', 478)
# ('believe', 421)
# ('them.', 371)
# ('themselves', 192)
# ('especially', 143)
# ('State', 801)

# %%
wcsort = wc.sortBy(lambda a: -a[1])
for c in wcsort.take(10):
    print(c)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ('the', 44647)
# ('of', 28020)
# ('to', 23208)
# ('and', 20444)
# ('in', 13174)
# ('that', 12265)
# ('I', 10880)
# ('a', 10431)
# ('is', 7776)
# ('be', 7148)

# %%
wc.saveAsTextFile("s3://notebooksnath/data/gutenberg-small/output")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
